# %%
## Pillow lib is the fork of PIL (Python Image Library). It makes the process easy to work with images
from PIL import Image

# %%
img1 = Image.open('image-1.jpg')

# %%
type(img1)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170>

# %%
img1.size
# Out:
# (297, 170)

# %%
img1.filename
# Out:
# 'image-1.jpg'

# %%
# CROPPING IMAGE

# Top left corner of the image
img1.crop((0,0,100,100))

# Bottom left corner
img1.crop((0,100,100,297))
# Out:
# <PIL.Image.Image image mode=RGB size=100x197>

# %%
# COLOR TRANSPARENCY
# RGBA = red, green, blue, alpha
img2 = Image.open('image-2.jpg') 
img3 = Image.open('image-3.jpg')

# %%
img2.putalpha(128)

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=275x183>
